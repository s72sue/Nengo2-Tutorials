# %% [markdown]
# # Routed Sequencing with Cleanup Memory

# %% [markdown]
# This model extends the routed sequencing model by creating a scalar ensemble 'cleanup' as explained in the book. You will project the 'state' on to the 'cleanup' ensemble using a transformation matrix 'pd', specified by the vocabulary vector 'A'. This implies that each component of the state vector (i.e., the cortical element) is multiplied by the corresponding component of the 'A' vector and summed to produce a one dimensional quantity represented by the 'cleanup' ensemble. This operation is similar to the dot product of the state vector and the vocabulary vector 'A'.

# %%
# Setup for the notebook
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import nengo
from nengo import spa
from nengo.spa import Vocabulary

# %% [markdown]
# ## Create the Model

# %% [markdown]
# This model has parameters as described in the book.

# %%
# Number of dimensions for the Semantic Pointers
dimensions = 16

# Make a model object with the SPA network
model = spa.SPA(label='Routed_Sequence with cleanupA')

with model:
    # Specifying the modules to be used
    model.state = spa.Buffer(dimensions=dimensions)
    model.vision = spa.Buffer(dimensions=dimensions) 
    
    # Specify the action mapping
    actions = spa.Actions(
        'dot(vision, START) --> state = vision',
        'dot(state, A) --> state = B',
        'dot(state, B) --> state = C',
        'dot(state, C) --> state = D',
        'dot(state, D) --> state = E',
        'dot(state, E) --> state = A'
    )
    
    # Creating the BG and Thalamus components that confirm to the specified rules
    model.BG = spa.BasalGanglia(actions=actions)
    model.thal = spa.Thalamus(model.BG)
    
    # Change the seed of this RNG to change the vocabulary
    rng = np.random.RandomState(0)
    vocab = Vocabulary(dimensions=dimensions)

    # Create the transformation matrix (pd) and the cleanup ensemble (cleanupA) 
    pd = [vocab['A'].v.tolist()] 
    cleanup = nengo.Ensemble(100, dimensions=1, label='Cleanup A')
    
    # Function that provides the model with an initial input semantic pointer.
    def start(t):
        if t < 0.05:
            return '0.8*START+D'
        else:
            return '0'

    # Input
    model.input = spa.Input(vision=start)
    
    # Projecting the state of the cortex on to the cleanup ensemble using a transformation matrix 'pd'.
    nengo.Connection(model.state.state.output, cleanup, transform=pd)

# %% [markdown]
# ## Add Probes to Collect Data

# %%
with model:
    state_p = nengo.Probe(model.state.state.output, synapse=0.01)
    vision_p = nengo.Probe(model.vision.state.output, synapse=0.01)
    actions_p = nengo.Probe(model.thal.actions.output, synapse=0.01)
    utility_p = nengo.Probe(model.BG.input, synapse=0.01)
    cleanup_p = nengo.Probe(cleanup, synapse=0.01)

# %% [markdown]
# ## Run the Model

# %%
sim = nengo.Simulator(model)      # Create the simulator
sim.run(0.5)     # Run it for 0.5 seconds

# %% [markdown]
# ## Plot the Results

# %%
fig = plt.figure(figsize=(12,8))
p1 = fig.add_subplot(4,1,1)
p1.plot(sim.trange(), model.similarity(sim.data, vision_p))
p1.legend(model.get_output_vocab('vision').keys, fontsize='x-small')
p1.set_ylabel('Vision')

p2 = fig.add_subplot(4,1,2)
p2.plot(sim.trange(), model.similarity(sim.data, state_p))
p2.legend(model.get_output_vocab('state').keys, fontsize='x-small')
p2.set_ylabel('State')

p3 = fig.add_subplot(4,1,3)
p3.plot(sim.trange(), sim.data[cleanup_p], 'k')
p3.set_ylabel('Cleanup')
p3.set_ylim(-0.6,0.8)

fig = plt.figure(figsize=(12,8))
p4 = fig.add_subplot(4,1,1)
p4.plot(sim.trange(), sim.data[actions_p])
p4_legend_txt = [a.effect for a in model.BG.actions.actions]
p4.legend(p4_legend_txt, fontsize='x-small')
p4.set_ylabel('Action')

p5 = fig.add_subplot(4,1,2)
p5.plot(sim.trange(), sim.data[utility_p])
p5_legend_txt = [a.condition for a in model.BG.actions.actions]
p5.legend(p5_legend_txt, fontsize='x-small')
p5.set_ylabel('Utility')


fig.subplots_adjust(hspace=0.2)

# %% [markdown]
# Since the cleanup operation is similar to a dot product between the state of the cortical element ('state') and the defined vocabulary vector 'A', the value of the cleanup population should rise only when the 'state' is 'A'. The second graph shows the semantic pointer representation of the values stored in the 'state' and the response of the cleanup population is shown in the third graph.
